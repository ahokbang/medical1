# %%
# 합계 컬럼을 생성해서 막대 그래프, 가로 막대 그래프를 출력하시오.
# 합계점수를 출력할 것
# 합계 = 국어+영어+수학+과학+사회

# %%
import pandas as pd
df = pd.read_csv('../z20_data/score.csv')

# %%
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호(-) 표기

x = df['이름']
y = df['합계']

plt.barh(x,y, color='violet')
plt.title('성적 그래프')
for i, txt in enumerate(y):
    plt.text(y[i]+13,x[i],txt, ha='center', color='blue')

# %%
x = df['이름']
y = df['합계']

plt.bar(x,y, color='purple')
for i, txt in enumerate(y):
    plt.text(x[i], y[1]+1.5, txt)
