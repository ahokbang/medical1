# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호(-) 표기

# %%
import pandas as pd
df = pd.read_csv('../z20_data/score.csv', index_col='지원번호')
df.head(3)
# Out:
#        이름   학교  학년    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197  90  85  100  95  85      Python
# 2번    강태원  구로고   3  184  40  35   50  55  25        Java
# 3번    강호림  구로고   2  168  80  75   70  80  75  javascript

# %%
x = df.head(10)['이름']
y = df.head(10)['국어']
y2 = df.head(10)['영어']
y3 = df.head(10)['수학']

# %%
# 꺽은 선 그래프
plt.plot(x,y, label='국어', marker='D')
plt.plot(x,y2, label='영어', marker='o', ls='--')
plt.plot(x,y3, label='수학', marker='s', linestyle='-.')
# 데이터(값) 표시
for i, txt in enumerate(y3):
    plt.text(x[i], y3[i]+2, txt, ha='center', color='red')
# ncols : 1줄에 표시되는 범례 수 지정
plt.legend(loc='upper center', ncols=3)
plt.show()
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_24380\1055232787.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i], y3[i]+2, txt, ha='center', color='red')

# %%
# 막대그래프
colors=['r','g','b','y','c']
plt.bar(x,y3, label='국어', color=colors)

for i, txt in enumerate(y3):
    plt.text(x[i], y3[i]+2, txt, ha='center', color='red')

plt.xticks(rotation=90) # x축 이름 각도 조정
plt.legend(loc='upper center', ncols=3)
plt.show()
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_24380\1830050979.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i], y3[i]+2, txt, ha='center', color='red')

# %%
x = df.head(3)['이름']
y3 = df.head(3)['수학']
# 막대그래프
# width : 막대 두께 조절
# alpha : 막대 투명도 조절
# plt.bar(x,y3, label='국어', width=0.3, alpha=0.5)
# 패턴 넣기
bar = plt.bar(x,y3, label='국어', width=0.3, alpha=0.5)
bar[0].set_hatch('/')
bar[1].set_hatch('x')
bar[2].set_hatch('..')

for i, txt in enumerate(y3):
    plt.text(x[i], y3[i]+2, txt, ha='center')

plt.xticks(rotation=90) # x축 이름 각도 조정
plt.legend(loc='upper center', ncols=3)
plt.show()
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_24380\1897451515.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(x[i], y3[i]+2, txt, ha='center')
