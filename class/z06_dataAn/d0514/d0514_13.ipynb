# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호(-) 표기

# %%
values = [10, 5, 10, 7, 6, 2] 
title = ['python', 'Java', 'Javascript', 'C#', 'C', 'ETC']
explode=[0.1]*6
colors=['powderblue', 'plum', 'pink', 'lightskyblue', 'deepskyblue','lavender']
wedgeprops={'width':0.6, 'edgecolor':'w', 'linewidth':2}

# %%
# values : 값
# labels: 표시(글자)
# autopct : 파이 내 글자 표시 및 퍼센트 표시
# startangle : 원형이 시작하는 위치
# colors : 그래프 색상
# counterclock : 그래프 내 데이터 배치 방향(False: 시계방향)
# wedgeprops : 그래프 테두리
# pctdistance : 파이 내 글자 표시 위치
plt.pie(values,labels=title, autopct='%1.f%%', startangle=90, counterclock=False, 
        colors=colors,wedgeprops=wedgeprops, pctdistance=0.7)
plt.legend(loc=(1.0, 0))
plt.show()
