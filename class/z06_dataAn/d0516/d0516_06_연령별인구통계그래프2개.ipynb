# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호(-) 표기

# %% [markdown]
# 연령별 인구현황
# - 2023년 1월 연령별 남여 인구 수를 가로막대그래프로 출력하시오.
# - 남자범위 : usecols='B,E:Y',여자범위 : usecols='B,AB:AV'

# %%
df = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx', skiprows=3, index_col='행정기관')
# df = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx', skiprows=3, thousands=',', index_col='행정기관')

# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 전국   to 제주특별자치도
# Columns: 185 entries, 행정기관코드 to 100세 이상.7
# dtypes: int64(1), object(184)
# memory usage: 26.2+ KB

# %%
df.index
# Out:
# Index(['전국  ', '서울특별시  ', '부산광역시  ', '대구광역시  ', '인천광역시  ', '광주광역시  ',
#        '대전광역시  ', '울산광역시  ', '세종특별자치시  ', '경기도  ', '강원도  ', '충청북도  ', '충청남도  ',
#        '전라북도  ', '전라남도  ', '경상북도  ', '경상남도  ', '제주특별자치도  '],
#       dtype='object', name='행정기관')

# %%
df.columns
# Out:
# Index(['행정기관코드', '남 인구수', '연령구간인구수', '0~4세', '5~9세', '10~14세', '15~19세',
#        '20~24세', '25~29세', '30~34세',
#        ...
#        '55~59세.7', '60~64세.7', '65~69세.7', '70~74세.7', '75~79세.7', '80~84세.7',
#        '85~89세.7', '90~94세.7', '95~99세.7', '100세 이상.7'],
#       dtype='object', length=185)

# %%
df.iloc[0]
# df.loc['전국  ']과 동일
# Out:
# 행정기관코드                0
# 남 인구수        25,631,538
# 연령구간인구수      25,631,538
# 0~4세            726,460
# 5~9세          1,072,653
#                 ...
# 80~84세.7        808,412
# 85~89세.7        471,121
# 90~94세.7        181,497
# 95~99세.7         41,465
# 100세 이상.7         7,089
# Name: 전국  , Length: 185, dtype: object

# %%
x = df.columns[3:24]
# x2 = df.columns[26:47]
# df.loc['전국  '][3:24].str.replace(',','').astype(int) # 천단위표시 제거
y = (df.loc['전국  '][3:24].str.replace(',','')).astype(int)//100 *-1
y2 = (df.loc['전국  '][26:47].str.replace(',','')).astype(int)//100
plt.barh(x,y, label='남성')
plt.barh(x,y2, label='여성')
plt.legend(loc=1)
plt.xticks(rotation=90)
plt.ylabel('연령')
plt.xlabel('인구 수')
plt.title('2021년 01월 대한민국 인구 피라미드')

plt.show()

# %% [markdown]
# 1월 ~ 4월 합산을 해서 가로 막대 그래프를 출력하시오.

# %%
# 천단위 표시(,) 제거
# df.iloc[0] = df.iloc[0].str.replace(",","").astype(int)

# %%
df['0~4세']
# Out:
# 행정기관
# 전국           726,460
# 서울특별시        116,614
# 부산광역시         41,333
# 대구광역시         31,269
# 인천광역시         43,664
# 광주광역시         21,506
# 대전광역시         21,241
# 울산광역시         16,646
# 세종특별자치시        9,524
# 경기도          216,863
# 강원도           20,663
# 충청북도          22,631
# 충청남도          31,138
# 전라북도          21,236
# 전라남도          23,539
# 경상북도          33,538
# 경상남도          44,066
# 제주특별자치도       10,989
# Name: 0~4세, dtype: object

# %%
df['0~4세'] = df['0~4세'].str.replace(",","").astype(int)+df['0~4세.2'].str.replace(",","").astype(int)+df['0~4세.4'].str.replace(",","").astype(int)+df['0~4세.6'].str.replace(",","").astype(int)
df['0~4세.1'] = df['0~4세.1'].str.replace(",","").astype(int)+df['0~4세.3'].str.replace(",","").astype(int)+df['0~4세.5'].str.replace(",","").astype(int)+df['0~4세.7'].str.replace(",","").astype(int)
df['5~9세'] = df['5~9세'].str.replace(",","").astype(int)+df['5~9세.2'].str.replace(",","").astype(int)+df['5~9세.4'].str.replace(",","").astype(int)+df['5~9세.6'].str.replace(",","").astype(int)
df['5~9세.1'] = df['5~9세.1'].str.replace(",","").astype(int)+df['5~9세.3'].str.replace(",","").astype(int)+df['5~9세.5'].str.replace(",","").astype(int)+df['5~9세.7'].str.replace(",","").astype(int)
df['10~14세'] = df['10~14세'].str.replace(",","").astype(int)+df['10~14세.2'].str.replace(",","").astype(int)+df['10~14세.4'].str.replace(",","").astype(int)+df['10~14세.6'].str.replace(",","").astype(int)
df['10~14세.1'] = df['10~14세.1'].str.replace(",","").astype(int)+df['10~14세.3'].str.replace(",","").astype(int)+df['10~14세.5'].str.replace(",","").astype(int)+df['10~14세.7'].str.replace(",","").astype(int)
df['15~19세'] = df['15~19세'].str.replace(",","").astype(int)+df['15~19세.2'].str.replace(",","").astype(int)+df['15~19세.4'].str.replace(",","").astype(int)+df['15~19세.6'].str.replace(",","").astype(int)
df['15~19세.1'] = df['15~19세.1'].str.replace(",","").astype(int)+df['15~19세.3'].str.replace(",","").astype(int)+df['15~19세.5'].str.replace(",","").astype(int)+df['15~19세.7'].str.replace(",","").astype(int)
df['20~24세'] = df['20~24세'].str.replace(",","").astype(int)+df['20~24세.2'].str.replace(",","").astype(int)+df['20~24세.4'].str.replace(",","").astype(int)+df['20~24세.5'].str.replace(",","").astype(int)
df['20~24세.1'] = df['20~24세.1'].str.replace(",","").astype(int)+df['20~24세.3'].str.replace(",","").astype(int)+df['20~24세.5'].str.replace(",","").astype(int)+df['20~24세.7'].str.replace(",","").astype(int)
df['25~29세'] = df['25~29세'].str.replace(",","").astype(int)+df['25~29세.2'].str.replace(",","").astype(int)+df['25~29세.4'].str.replace(",","").astype(int)+df['25~29세.6'].str.replace(",","").astype(int)
df['25~29세.1'] = df['25~29세.1'].str.replace(",","").astype(int)+df['25~29세.3'].str.replace(",","").astype(int)+df['25~29세.5'].str.replace(",","").astype(int)+df['25~29세.7'].str.replace(",","").astype(int)
df['30~34세'] = df['30~34세'].str.replace(",","").astype(int)+df['30~34세.2'].str.replace(",","").astype(int)+df['30~34세.4'].str.replace(",","").astype(int)+df['30~34세.6'].str.replace(",","").astype(int)
df['30~34세.1'] = df['30~34세.1'].str.replace(",","").astype(int)+df['30~34세.3'].str.replace(",","").astype(int)+df['30~34세.5'].str.replace(",","").astype(int)+df['30~34세.7'].str.replace(",","").astype(int)
df['35~39세'] = df['35~39세'].str.replace(",","").astype(int)+df['35~39세.2'].str.replace(",","").astype(int)+df['35~39세.4'].str.replace(",","").astype(int)+df['35~39세.6'].str.replace(",","").astype(int)
df['35~39세.1'] = df['35~39세.1'].str.replace(",","").astype(int)+df['35~39세.3'].str.replace(",","").astype(int)+df['35~39세.5'].str.replace(",","").astype(int)+df['35~39세.7'].str.replace(",","").astype(int)
df['40~44세'] = df['40~44세'].str.replace(",","").astype(int)+df['40~44세.2'].str.replace(",","").astype(int)+df['40~44세.4'].str.replace(",","").astype(int)+df['40~44세.6'].str.replace(",","").astype(int)
df['40~44세.1'] = df['40~44세.1'].str.replace(",","").astype(int)+df['40~44세.3'].str.replace(",","").astype(int)+df['40~44세.5'].str.replace(",","").astype(int)+df['40~44세.7'].str.replace(",","").astype(int)
df['45~49세'] = df['45~49세'].str.replace(",","").astype(int)+df['45~49세.2'].str.replace(",","").astype(int)+df['45~49세.4'].str.replace(",","").astype(int)+df['45~49세.6'].str.replace(",","").astype(int)
df['45~49세.1'] = df['45~49세.1'].str.replace(",","").astype(int)+df['45~49세.3'].str.replace(",","").astype(int)+df['45~49세.5'].str.replace(",","").astype(int)+df['45~49세.7'].str.replace(",","").astype(int)
df['50~54세'] = df['50~54세'].str.replace(",","").astype(int)+df['50~54세.2'].str.replace(",","").astype(int)+df['50~54세.4'].str.replace(",","").astype(int)+df['50~54세.6'].str.replace(",","").astype(int)
df['50~54세.1'] = df['50~54세.1'].str.replace(",","").astype(int)+df['50~54세.3'].str.replace(",","").astype(int)+df['50~54세.5'].str.replace(",","").astype(int)+df['50~54세.7'].str.replace(",","").astype(int)
df['55~59세'] = df['55~59세'].str.replace(",","").astype(int)+df['55~59세.2'].str.replace(",","").astype(int)+df['55~59세.4'].str.replace(",","").astype(int)+df['55~59세.6'].str.replace(",","").astype(int)
df['55~59세.1'] = df['55~59세.1'].str.replace(",","").astype(int)+df['55~59세.3'].str.replace(",","").astype(int)+df['55~59세.5'].str.replace(",","").astype(int)+df['55~59세.7'].str.replace(",","").astype(int)
df['60~64세'] = df['60~64세'].str.replace(",","").astype(int)+df['60~64세.2'].str.replace(",","").astype(int)+df['60~64세.4'].str.replace(",","").astype(int)+df['60~64세.6'].str.replace(",","").astype(int)
df['60~64세.1'] = df['60~64세.1'].str.replace(",","").astype(int)+df['60~64세.3'].str.replace(",","").astype(int)+df['60~64세.5'].str.replace(",","").astype(int)+df['60~64세.7'].str.replace(",","").astype(int)
df['65~69세'] = df['65~69세'].str.replace(",","").astype(int)+df['65~69세.2'].str.replace(",","").astype(int)+df['65~69세.4'].str.replace(",","").astype(int)+df['65~69세.6'].str.replace(",","").astype(int)
df['65~69세.1'] = df['65~69세.1'].str.replace(",","").astype(int)+df['65~69세.3'].str.replace(",","").astype(int)+df['65~69세.5'].str.replace(",","").astype(int)+df['65~69세.7'].str.replace(",","").astype(int)
df['70~74세'] = df['70~74세'].str.replace(",","").astype(int)+df['70~74세.2'].str.replace(",","").astype(int)+df['70~74세.4'].str.replace(",","").astype(int)+df['70~74세.6'].str.replace(",","").astype(int)
df['70~74세.1'] = df['70~74세.1'].str.replace(",","").astype(int)+df['70~74세.3'].str.replace(",","").astype(int)+df['70~74세.5'].str.replace(",","").astype(int)+df['70~74세.7'].str.replace(",","").astype(int)
df['75~79세'] = df['75~79세'].str.replace(",","").astype(int)+df['75~79세.2'].str.replace(",","").astype(int)+df['75~79세.4'].str.replace(",","").astype(int)+df['75~79세.6'].str.replace(",","").astype(int)
df['75~79세.1'] = df['75~79세.1'].str.replace(",","").astype(int)+df['75~79세.3'].str.replace(",","").astype(int)+df['75~79세.5'].str.replace(",","").astype(int)+df['75~79세.7'].str.replace(",","").astype(int)
df['80~84세'] = df['80~84세'].str.replace(",","").astype(int)+df['80~84세.2'].str.replace(",","").astype(int)+df['80~84세.4'].str.replace(",","").astype(int)+df['80~84세.3'].str.replace(",","").astype(int)
df['80~84세.1'] = df['80~84세.1'].str.replace(",","").astype(int)+df['80~84세.3'].str.replace(",","").astype(int)+df['80~84세.5'].str.replace(",","").astype(int)+df['80~84세.7'].str.replace(",","").astype(int)
df['85~89세'] = df['85~89세'].str.replace(",","").astype(int)+df['85~89세.2'].str.replace(",","").astype(int)+df['85~89세.4'].str.replace(",","").astype(int)+df['85~89세.6'].str.replace(",","").astype(int)
df['85~89세.1'] = df['85~89세.1'].str.replace(",","").astype(int)+df['85~89세.3'].str.replace(",","").astype(int)+df['85~89세.5'].str.replace(",","").astype(int)+df['85~89세.7'].str.replace(",","").astype(int)
df['90~94세'] = df['90~94세'].str.replace(",","").astype(int)+df['90~94세.2'].str.replace(",","").astype(int)+df['90~94세.4'].str.replace(",","").astype(int)+df['90~94세.6'].str.replace(",","").astype(int)
df['90~94세.1'] = df['90~94세.1'].str.replace(",","").astype(int)+df['90~94세.3'].str.replace(",","").astype(int)+df['90~94세.5'].str.replace(",","").astype(int)+df['90~94세.7'].str.replace(",","").astype(int)
df['95~99세'] = df['95~99세'].str.replace(",","").astype(int)+df['95~99세.2'].str.replace(",","").astype(int)+df['95~99세.4'].str.replace(",","").astype(int)+df['95~99세.6'].str.replace(",","").astype(int)
df['95~99세.1'] = df['95~99세.1'].str.replace(",","").astype(int)+df['95~99세.3'].str.replace(",","").astype(int)+df['95~99세.5'].str.replace(",","").astype(int)+df['95~99세.7'].str.replace(",","").astype(int)
df['100세 이상'] = df['100세 이상'].str.replace(",","").astype(int)+df['100세 이상.2'].str.replace(",","").astype(int)+df['100세 이상.4'].str.replace(",","").astype(int)+df['100세 이상.6'].str.replace(",","").astype(int)
df['100세 이상.1'] = df['100세 이상.1'].str.replace(",","").astype(int)+df['100세 이상.3'].str.replace(",","").astype(int)+df['100세 이상.5'].str.replace(",","").astype(int)+df['100세 이상.7'].str.replace(",","").astype(int)

# %%
x = df.columns[3:24]
y = -(df.loc['전국  '][3:24])//100
y2 = (df.loc['전국  '][3:24])//100


plt.barh(x,y, label='남성')
plt.barh(x,y2, label='여성')
plt.legend(loc=1)
