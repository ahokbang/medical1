# %%
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호(-) 표기

# %%
df = pd.read_csv('../z20_data/02.iris.csv')
df.head(3)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Name         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %% [markdown]
# 1. 데이터 전처리 : train_data, test_data 분리

# %%
# 정답이 있는 데이터 (정답=name)이므로 데이터와 정답 분리 필요
# 데이터
df[['SepalLength','SepalWidth','PetalLength','PetalWidth']]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
df['Name'] # 정답
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Name, Length: 150, dtype: object

# %%
# rows 100개(0~99)를 출력하시오. train_input
# df[0:99]
# SepalLength, SepalWidth, PetalLength, PetalWidth
# train_input = df[['SepalLength','SepalWidth','PetalLength','PetalWidth']][0:99]

# tc ==> 데이터.iloc[행(:), 열(:)] 사용하면 행, 열 한번에 슬라이싱 가능
train_input = df.iloc[:100,:-1]

# %%
# rows 50개(0~49)를 출력하시오. test_input
# SepalLength, SepalWidth, PetalLength, PetalWidth
test_input = df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']][0:49]

# %%
# rows 100개(0~99)를 출력하시오. train_target
# Name
train_target = df[['Name']][0:99]
train_target
# Out:
#                Name
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 94  Iris-versicolor
# 95  Iris-versicolor
# 96  Iris-versicolor
# 97  Iris-versicolor
# 98  Iris-versicolor
#
# [99 rows x 1 columns]

# %%
# rows 50개(0~49)를 출력하시오. test_target
# Name
test_target = df[['Name']][0:49]
test_target
# Out:
#            Name
# 0   Iris-setosa
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa
# 6   Iris-setosa
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa
# 12  Iris-setosa
# 13  Iris-setosa
# 14  Iris-setosa
# 15  Iris-setosa
# 16  Iris-setosa
# 17  Iris-setosa
# 18  Iris-setosa
# 19  Iris-setosa
# 20  Iris-setosa
# 21  Iris-setosa
# 22  Iris-setosa
# 23  Iris-setosa
# 24  Iris-setosa
# 25  Iris-setosa
# 26  Iris-setosa
# 27  Iris-setosa
# 28  Iris-setosa
# 29  Iris-setosa
# 30  Iris-setosa
# 31  Iris-setosa
# 32  Iris-setosa
# 33  Iris-setosa
# 34  Iris-setosa
# 35  Iris-setosa
# 36  Iris-setosa
# 37  Iris-setosa
# 38  Iris-setosa
# 39  Iris-setosa
# 40  Iris-setosa
# 41  Iris-setosa
# 42  Iris-setosa
# 43  Iris-setosa
# 44  Iris-setosa
# 45  Iris-setosa
# 46  Iris-setosa
# 47  Iris-setosa
# 48  Iris-setosa

# %%
# iloc(row, column) 
train_input = df.iloc[:100, :-1]
test_input = df.iloc[100:, :-1]
train_target = df.iloc[:100, 4]
test_target = df.iloc[100:, 4]

# %% [markdown]
# 2. 데이터 학습시키기

# %%
clf = svm.SVC()
# 데이터 훈련
clf.fit(train_input, train_target)
# Out:
# SVC()

# %% [markdown]
# 3. 데이터 예측하기

# %%
result = clf.predict(test_input)

# %% [markdown]
# 4. 정답률 구하기

# %%
score = metrics.accuracy_score(test_target, result)
print("정답률 : ", score)
# Out:
# 정답률 :  0.0

# %% [markdown]
# 정답률 0으로 데이터 섞어주야 함.

# %%
# 방법 1 : numpy random 함수 
# random code 0-149 랜덤숫자를 생성 (numpy 사용)
# np.random.seed(150)
# # 150개(0-149) 배열 생성
# index = np.arange(150)
# np.random.shuffle(index)
# print(index)
# Out:
# [ 53  42 141  83  60  28  13  31  71  59   2 124 131  54 144  36  52 139
#  128 114  63  91  16   8  87  76  35 117 109  88  72  84  21  43  85 137
#  134  48  30  27  47  41  90  33 145  79  40  20  34  11 136 113  32 119
#   78 125   3  96  82  86   6 118 111 143  69 129 140  62  99  65  97  39
#   98  57  73  51  77 149  94  29 120  56   4   9  37   1  44 106 148  22
#  102  66  18  24  58  89  61 115 132   0   5  10 133  70 112 146 126 107
#   80 123  46 147 122  75  15  68  95  26  12 127  55 103  67 130  19  64
#   74 135 110  45  23 108  38   7 121  93  81 138 116  17  49  14 104 105
#   92 101 142 100  50  25]

# %%
# 방법 2 : 파이썬 random 함수
# range(149)
# ran_num = [i for i in range(150)]
# random.shuffle(ran_num)
# ran_num
# Out:
# [22,
#  68,
#  108,
#  34,
#  93,
#  85,
#  8,
#  84,
#  6,
#  38,
#  113,
#  16,
#  24,
#  100,
#  35,
#  52,
#  30,
#  32,
#  54,
#  1,
#  21,
#  126,
#  89,
#  29,
#  63,
#  15,
#  128,
#  97,
#  53,
#  27,
#  72,
#  4,
#  36,
#  77,
#  144,
#  117,
#  12,
#  127,
#  92,
#  91,
#  82,
#  121,
#  105,
#  109,
#  132,
#  94,
#  47,
#  103,
#  10,
#  125,
#  96,
#  137,
#  46,
#  37,
#  44,
#  148,
#  120,
#  99,
#  107,
#  135,
#  62,
#  130,
#  102,
#  147,
#  3,
#  90,
#  129,
#  118,
#  40,
#  98,
#  112,
#  87,
#  0,
#  28,
#  80,
#  133,
#  50,
#  115,
#  41,
#  110,
#  57,
#  134,
#  61,
#  70,
#  86,
#  59,
#  136,
#  139,
#  104,
#  79,
#  143,
#  149,
#  114,
#  88,
#  131,
#  138,
#  64,
#  141,
#  2,
#  76,
#  124,
#  13,
#  56,
#  106,
#  83,
#  116,
#  17,
#  146,
#  42,
#  81,
#  11,
#  119,
#  31,
#  74,
#  33,
#  14,
#  66,
#  73,
#  5,
#  9,
#  95,
#  75,
#  25,
#  140,
#  7,
#  60,
#  123,
#  20,
#  142,
#  48,
#  43,
#  71,
#  18,
#  145,
#  101,
#  51,
#  69,
# ...

# %%
# index로 df에 대입해서 가져오면, 랜덤으로 데이터가 섞여서 가져올 수 있음.
# train_input = df.iloc[ran_num[:100],:-1]
# train_input
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 22           4.6         3.6          1.0         0.2
# 68           6.2         2.2          4.5         1.5
# 108          6.7         2.5          5.8         1.8
# 34           4.9         3.1          1.5         0.1
# 93           5.0         2.3          3.3         1.0
# ..           ...         ...          ...         ...
# 138          6.0         3.0          4.8         1.8
# 64           5.6         2.9          3.6         1.3
# 141          6.9         3.1          5.1         2.3
# 2            4.7         3.2          1.3         0.2
# 76           6.8         2.8          4.8         1.4
#
# [100 rows x 4 columns]

# %% [markdown]
# 랜덤함수 생성 후 데이터 가져오기

# %%
# 1. 데이터 전처리
# 랜덤으로 데이터 추출 : train data와 test data를 수동으로 분리
# train_input = df.iloc[ran_num[:100],:-1]
# test_input = df.iloc[ran_num[100:],:-1]
# train_target = df.iloc[ran_num[:100],4]
# test_target = df.iloc[ran_num[100:],4]

# %%
# 1. 데이터 전처리 : data, result 데이터 분리
datas_input = df.iloc[:,:-1] # 모든 데이터
datas_target = df.iloc[:,-1] # 모든 정답

# 모든 data를 가지고, train, test 데이터 분리
from sklearn.model_selection import train_test_split # train data와 test data를 자동으로 분리
train_input, test_input, train_target, test_target = train_test_split(datas_input, datas_target)

# %%
#2. 데이터 학습시키기 : 모델 선정 후 데이터 훈련
clf = svm.SVC()
clf.fit(train_input, train_target)

# 3. 데이터 예측하기
result = clf.predict(test_input)

# 4. 정답률 구하기 : 2가지 형태
# score = metrics.accuracy_score(test_target, result)
score = clf.score(test_input, test_target)

print('정답률 : ',score)
# Out:
# 정답률 :  0.9210526315789473

# %% [markdown]
# 결과값 test

# %%
# 아래 데이터 입력 후 무슨 품종인지 출력하시오.
# 4.9, 2.9, 1.4, 0.2    # Iris-setosa
# 5.6, 3, 4.1, 1.2      # Iris-versicolor
# 6.5, 2.8, 6.7, 2.2    # Iris-virginica

num1 = input("데이터 1을 입력하시오. >> ")
num2 = input("데이터 2를 입력하시오. >> ")
num3 = input("데이터 3을 입력하시오. >> ")
num4 = input("데이터 4를 입력하시오. >> ")

nums = [num1, num2, num3, num4]

result = clf.predict([nums])
print('정답 : ', result)
# Out:
# 정답 :  ['Iris-virginica']
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
