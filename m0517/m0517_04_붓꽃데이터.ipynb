# %%
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글설정
matplotlib.rcParams['font.size'] = 10 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호(-) 표기

# %%
df = pd.read_csv('../z20_data/02.iris.csv')
df.head(3)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
# 1. 데이터 전처리 : data와 result로 분리(데이터 분리)
datas = df.iloc[:,:-1] # df[['SepalLength','SepalWidth', 'PetalLength','PetalWidth]]
results = df.iloc[:,4] # df['Name']

# %%
# train, test 데이터 분리 : 자동으로 랜덤하게 분리해 줌.
train_input, test_input, train_target, test_target = train_test_split(datas, results)

# %%
# 2. 데이터 학습시키기
clf = svm.SVC()
clf.fit(train_input, train_target)
# Out:
# SVC()

# %%
test_input
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 79           5.7         2.6          3.5         1.0
# 84           5.4         3.0          4.5         1.5
# 45           4.8         3.0          1.4         0.3
# 124          6.7         3.3          5.7         2.1
# 143          6.8         3.2          5.9         2.3
# 87           6.3         2.3          4.4         1.3
# 15           5.7         4.4          1.5         0.4
# 104          6.5         3.0          5.8         2.2
# 130          7.4         2.8          6.1         1.9
# 26           5.0         3.4          1.6         0.4
# 25           5.0         3.0          1.6         0.2
# 94           5.6         2.7          4.2         1.3
# 137          6.4         3.1          5.5         1.8
# 149          5.9         3.0          5.1         1.8
# 74           6.4         2.9          4.3         1.3
# 97           6.2         2.9          4.3         1.3
# ...

# %%
# 3. 데이터 예측하기
pre = clf.predict(test_input)
print("test 질문의 답 : ", pre)

# %%
len(test_input)
# Out:
# 38

# %%
# 4. 정답률 구하기
score = clf.score(test_input, test_target)
print("정답률 : ", score)
# Out:
# 정답률 :  1.0

# %%
# 아래 데이터 입력 후 무슨 품종인지 출력하시오.
# 4.9, 2.9, 1.4, 0.2    # Iris-setosa
# 5.6, 3, 4.1, 1.2      # Iris-versicolor
# 6.5, 2.8, 6.7, 2.2    # Iris-virginica

# 위의 문제는 데이터 예측하기에 넣어주는 것.

data1 = [4.9, 2.9, 1.4, 0.2]
data2 = [5.6, 3, 4.1, 1.2]
data3 = [6.5, 2.8, 6.7, 2.2]
data4 = [data1, data2, data3]

# %%
# 3. 데이터 예측하기
pre = clf.predict(data4)
print("test 질문의 답 : ", pre)
# Out:
# test 질문의 답 :  ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
input1 = input("데이터를 입력하세요. >> ")
print(input1)
input_arr = input1.split(',')
print(input_arr) # float으로 타입 변경해야 해.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 input1 = float(input("데이터를 입력하세요. >> "))
#       2 print(input1)
#       3 input_arr = input1.split(',')
#
# ValueError: could not convert string to float: '4.9,2.9,1.4,0.2'
